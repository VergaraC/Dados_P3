# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import math as math
from scipy import stats
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("data.xlsx")
data.head()
# Out:
#               R_fighter       B_fighter          Referee        date  \
# 0          Henry Cejudo   Marlon Moraes     Marc Goddard  2019-06-08
# 1  Valentina Shevchenko     Jessica Eye  Robert Madrigal  2019-06-08
# 2         Tony Ferguson  Donald Cerrone  Dan Miragliotta  2019-06-08
# 3         Jimmie Rivera        Petr Yan  Kevin MacDonald  2019-06-08
# 4           Tai Tuivasa   Blagoy Ivanov  Dan Miragliotta  2019-06-08
#
#                  location Winner  title_bout       weight_class  no_of_rounds  \
# 0  Chicago, Illinois, USA    Red        True       Bantamweight             5
# 1  Chicago, Illinois, USA    Red        True  Women's Flyweight             5
# 2  Chicago, Illinois, USA    Red       False        Lightweight             3
# 3  Chicago, Illinois, USA   Blue       False       Bantamweight             3
# 4  Chicago, Illinois, USA   Blue       False        Heavyweight             3
#
#    B_current_lose_streak  ...    R_win_by_KO/TKO  R_win_by_Submission  \
# 0                      0  ...                  2                    0
# 1                      0  ...                  0                    2
# 2                      0  ...                  3                    6
# 3                      0  ...                  1                    0
# 4                      0  ...                  2                    0
#
#    R_win_by_TKO_Doctor_Stoppage  R_wins  R_Stance  R_Height_cms  R_Reach_cms  \
# 0                             0       8  Orthodox        162.56       162.56
# 1                             0       5  Southpaw        165.10       167.64
# 2                             1      14  Orthodox        180.34       193.04
# 3                             0       6  Orthodox        162.56       172.72
# 4                             0       3  Southpaw        187.96       190.50
#
#    R_Weight_lbs  B_age  R_age
# 0         135.0   31.0   32.0
# 1         125.0   32.0   31.0
# 2         155.0   36.0   35.0
# 3         135.0   26.0   29.0
# 4         264.0   32.0   26.0
#
# [5 rows x 145 columns]

# %% [markdown]
# ### Apenas a categoria Peso-Pesados ('Heavyweights')

# %%
data.weight_class = data.weight_class.astype('category')

# %%
data_heavy = data.loc[(data.weight_class=='Heavyweight'),:]
data_heavy1 = data_heavy.loc[:,['R_fighter','B_fighter','date','Winner','weight_class','R_wins','R_losses','B_wins','B_losses','B_Reach_cms','B_Height_cms','B_Weight_lbs','R_Reach_cms','R_Height_cms','R_Weight_lbs']]

# %%
data_heavy1.head()
# Out:
#           R_fighter          B_fighter        date Winner weight_class  \
# 4       Tai Tuivasa      Blagoy Ivanov  2019-06-08   Blue  Heavyweight
# 54      Walt Harris     Serghei Spivac  2019-05-04    Red  Heavyweight
# 60    Arjan Bhullar         Juan Adams  2019-05-04    Red  Heavyweight
# 63       Greg Hardy  Dmitrii Smoliakov  2019-04-27    Red  Heavyweight
# 69  Andrei Arlovski      Augusto Sakai  2019-04-27   Blue  Heavyweight
#
#     R_wins  R_losses  B_wins  B_losses  B_Reach_cms  B_Height_cms  \
# 4        3         1       1         1       185.42        180.34
# 54       4         7       0         0       198.12        190.50
# 60       2         1       1         0       203.20        195.58
# 63       0         1       0         2       187.96        187.96
# 69      16        12       1         0       195.58        190.50
#
#     B_Weight_lbs  R_Reach_cms  R_Height_cms  R_Weight_lbs
# 4          250.0       190.50        187.96         264.0
# 54         260.0       195.58        195.58         250.0
# 60         265.0       190.50        185.42         245.0
# 63         253.0       203.20        195.58         265.0
# 69         265.0       195.58        190.50         240.0

# %% [markdown]
# ## Como fazer os Betas

# %%
Y = df["Winner"]
X3 = df[['cylinders','acceleration']]

result = regress(X,Y)
result.summary()

# %%
Beta.append[results3.params["const"]]
Beta.append[results3.params["cylinders"]]
Beta.append[results3.params["acceleration"]]
