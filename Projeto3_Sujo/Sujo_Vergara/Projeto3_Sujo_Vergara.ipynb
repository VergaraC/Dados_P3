# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import math as math
import statsmodels.api as sm
from scipy import stats
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("data.xlsx")
data.head()
# Out:
#               R_fighter       B_fighter          Referee  date  \
# 0          Henry Cejudo   Marlon Moraes     Marc Goddard  2019
# 1  Valentina Shevchenko     Jessica Eye  Robert Madrigal  2019
# 2         Tony Ferguson  Donald Cerrone  Dan Miragliotta  2019
# 3         Jimmie Rivera        Petr Yan  Kevin MacDonald  2019
# 4           Tai Tuivasa   Blagoy Ivanov  Dan Miragliotta  2019
#
#                  location Winner  title_bout       weight_class  no_of_rounds  \
# 0  Chicago, Illinois, USA    Red        True       Bantamweight             5
# 1  Chicago, Illinois, USA    Red        True  Women's Flyweight             5
# 2  Chicago, Illinois, USA    Red       False        Lightweight             3
# 3  Chicago, Illinois, USA   Blue       False       Bantamweight             3
# 4  Chicago, Illinois, USA   Blue       False        Heavyweight             3
#
#    B_current_lose_streak  ...    R_win_by_KO/TKO  R_win_by_Submission  \
# 0                      0  ...                  2                    0
# 1                      0  ...                  0                    2
# 2                      0  ...                  3                    6
# 3                      0  ...                  1                    0
# 4                      0  ...                  2                    0
#
#    R_win_by_TKO_Doctor_Stoppage  R_wins  R_Stance  R_Height_cms  R_Reach_cms  \
# 0                             0       8  Orthodox        162.56       162.56
# 1                             0       5  Southpaw        165.10       167.64
# 2                             1      14  Orthodox        180.34       193.04
# 3                             0       6  Orthodox        162.56       172.72
# 4                             0       3  Southpaw        187.96       190.50
#
#    R_Weight_lbs  B_age  R_age
# 0         135.0   31.0   32.0
# 1         125.0   32.0   31.0
# 2         155.0   36.0   35.0
# 3         135.0   26.0   29.0
# 4         264.0   32.0   26.0
#
# [5 rows x 145 columns]

# %% [markdown]
# ### Apenas a categoria Peso-Pesados ('Heavyweights')

# %%
#data.weight_class = data.weight_class.astype('category')

# %%
data_heavy = data.loc[(data.weight_class=='Heavyweight'),:]
bool_to_number = {False: 0, True: 1}
string_to_number = {'Blue': 0, 'Red': 1}
data_heavy['title_bout'] = data_heavy['title_bout'].map(bool_to_number)
data_heavy['Winner'] = data_heavy['Winner'].map(string_to_number)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
data_heavy.head(2)
# Out:
#       R_fighter       B_fighter          Referee  date  \
# 4   Tai Tuivasa   Blagoy Ivanov  Dan Miragliotta  2019
# 54  Walt Harris  Serghei Spivac      Jerin Valel  2019
#
#                    location  Winner  title_bout weight_class  no_of_rounds  \
# 4    Chicago, Illinois, USA     0.0           0  Heavyweight             3
# 54  Ottawa, Ontario, Canada     1.0           0  Heavyweight             3
#
#     B_current_lose_streak  ...    R_win_by_KO/TKO  R_win_by_Submission  \
# 4                       0  ...                  2                    0
# 54                      0  ...                  4                    0
#
#     R_win_by_TKO_Doctor_Stoppage  R_wins  R_Stance  R_Height_cms  R_Reach_cms  \
# 4                              0       3  Southpaw        187.96       190.50
# 54                             0       4  Southpaw        195.58       195.58
#
#     R_Weight_lbs  B_age  R_age
# 4          264.0   32.0   26.0
# 54         250.0   24.0   35.0
#
# [2 rows x 145 columns]

# %% [markdown]
# ## Como fazer os Betas

# %%
def preparo(X,Y):
    X_cp = sm.add_constant(X)
    model = sm.OLS(Y,X_cp,missing='drop')
    results = model.fit()
    return results

# %%
Y = data_heavy["Winner"]
#X = data_heavy[['title_bout','R_Stance']]
X=data_heavy[['R_Height_cms','R_Weight_lbs']]
#np.asarray(X)
X[X['R_Weight_lbs'].isnull()==True]
# Out:
# Empty DataFrame
# Columns: [R_Height_cms, R_Weight_lbs]
# Index: []

# %%
result = preparo(X,Y)
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Winner   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     2.923
# Date:                Tue, 12 Nov 2019   Prob (F-statistic):             0.0547
# Time:                        15:46:59   Log-Likelihood:                -277.61
# No. Observations:                 497   AIC:                             561.2
# Df Residuals:                     494   BIC:                             573.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            1.0254      0.555      1.847      0.065      -0.065       2.116
# R_Height_cms     0.0016      0.003      0.504      0.615      -0.005       0.008
# R_Weight_lbs    -0.0023      0.001     -2.399      0.017      -0.004      -0.000
# ==============================================================================
# Omnibus:                       88.164   Durbin-Watson:                   1.535
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              125.197
# Skew:                          -1.206   Prob(JB):                     6.51e-28
# Kurtosis:                       2.519   Cond. No.                     9.06e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.06e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
Beta=[]

'''Beta.append[result.params["const"]]
Beta.append[result.params['title_bout']]
Beta.append[result.params['R_Stance']]'''
# Out:
# 'Beta.append[result.params["const"]]\nBeta.append[result.params[\'title_bout\']]\nBeta.append[result.params[\'R_Stance\']]'

# %% [markdown]
# # Referências

# %% [markdown]
# [Como funciona regressão linear](https://www.saedsayad.com/logistic_regression.htm)
#
# [Como usar a biblioteca Scikit-lear](https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression)
