# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import math as math
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel("data.xlsx")
data.head()
# Out:
#               R_fighter       B_fighter          Referee  date  \
# 0          Henry Cejudo   Marlon Moraes     Marc Goddard  2019
# 1  Valentina Shevchenko     Jessica Eye  Robert Madrigal  2019
# 2         Tony Ferguson  Donald Cerrone  Dan Miragliotta  2019
# 3         Jimmie Rivera        Petr Yan  Kevin MacDonald  2019
# 4           Tai Tuivasa   Blagoy Ivanov  Dan Miragliotta  2019
#
#                  location Winner  title_bout       weight_class  no_of_rounds  \
# 0  Chicago, Illinois, USA    Red        True       Bantamweight             5
# 1  Chicago, Illinois, USA    Red        True  Women's Flyweight             5
# 2  Chicago, Illinois, USA    Red       False        Lightweight             3
# 3  Chicago, Illinois, USA   Blue       False       Bantamweight             3
# 4  Chicago, Illinois, USA   Blue       False        Heavyweight             3
#
#    B_current_lose_streak  ...    R_win_by_KO/TKO  R_win_by_Submission  \
# 0                      0  ...                  2                    0
# 1                      0  ...                  0                    2
# 2                      0  ...                  3                    6
# 3                      0  ...                  1                    0
# 4                      0  ...                  2                    0
#
#    R_win_by_TKO_Doctor_Stoppage  R_wins  R_Stance  R_Height_cms  R_Reach_cms  \
# 0                             0       8  Orthodox        162.56       162.56
# 1                             0       5  Southpaw        165.10       167.64
# 2                             1      14  Orthodox        180.34       193.04
# 3                             0       6  Orthodox        162.56       172.72
# 4                             0       3  Southpaw        187.96       190.50
#
#    R_Weight_lbs  B_age  R_age
# 0         135.0   31.0   32.0
# 1         125.0   32.0   31.0
# 2         155.0   36.0   35.0
# 3         135.0   26.0   29.0
# 4         264.0   32.0   26.0
#
# [5 rows x 145 columns]

# %% [markdown]
# ### Apenas a categoria Peso-Pesados ('Heavyweights')

# %%
data.weight_class = data.weight_class.astype('category')
data.Winner = data.Winner.astype('category')

# %%
data.Winner.value_counts()
# Out:
# Red     3470
# Blue    1591
# Draw      83
# Name: Winner, dtype: int64

# %% [markdown]
# ### Blue = 0
# ### Red = 1

# %%
data_heavy = data.loc[(data.weight_class=='Heavyweight'),:]
bool_to_number = {False: 0, True: 1}
string_to_number = {'Blue': 0, 'Red': 1, 'Draw': 2}
data_heavy['title_bout'] = data_heavy['title_bout'].map(bool_to_number)
data_heavy['Winner'] = data_heavy['Winner'].map(string_to_number)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
data_heavy_util = data_heavy.drop(['Referee','date','location'], axis=1)

# %%
data_heavy_util.head()
# Out:
#           R_fighter          B_fighter  Winner  title_bout weight_class  \
# 4       Tai Tuivasa      Blagoy Ivanov       0           0  Heavyweight
# 54      Walt Harris     Serghei Spivac       1           0  Heavyweight
# 60    Arjan Bhullar         Juan Adams       1           0  Heavyweight
# 63       Greg Hardy  Dmitrii Smoliakov       1           0  Heavyweight
# 69  Andrei Arlovski      Augusto Sakai       0           0  Heavyweight
#
#     no_of_rounds  B_current_lose_streak  B_current_win_streak  B_draw  \
# 4              3                      0                     1       0
# 54             3                      0                     0       0
# 60             3                      0                     1       0
# 63             3                      2                     0       0
# 69             3                      0                     1       0
#
#     B_avg_BODY_att  ...    R_win_by_KO/TKO  R_win_by_Submission  \
# 4             17.0  ...                  2                    0
# 54             NaN  ...                  4                    0
# 60             8.0  ...                  0                    0
# 63             5.0  ...                  0                    0
# 69            35.0  ...                  9                    2
#
#     R_win_by_TKO_Doctor_Stoppage  R_wins  R_Stance  R_Height_cms  R_Reach_cms  \
# 4                              0       3  Southpaw        187.96       190.50
# 54                             0       4  Southpaw        195.58       195.58
# 60                             0       2  Orthodox        185.42       190.50
# 63                             0       0  Orthodox        195.58       203.20
# 69                             0      16  Orthodox        190.50       195.58
#
#     R_Weight_lbs  B_age  R_age
# 4          264.0   32.0   26.0
# 54         250.0   24.0   35.0
# 60         245.0   27.0   32.0
# 63         265.0   36.0   30.0
# 69         240.0   27.0   40.0
#
# [5 rows x 142 columns]

# %%
colunas = list(data_heavy_util)

# %%
colunas.remove('R_fighter')
colunas.remove('B_fighter')
colunas.remove('title_bout')
colunas.remove('weight_class')
colunas.remove('no_of_rounds')
colunas.remove('B_total_rounds_fought')
colunas.remove('R_total_rounds_fought')

# %%
dataf = data_heavy_util.loc[:,colunas]
dataf.head()
# Out:
#     Winner  B_current_lose_streak  B_current_win_streak  B_draw  \
# 4        0                      0                     1       0
# 54       1                      0                     0       0
# 60       1                      0                     1       0
# 63       1                      2                     0       0
# 69       0                      0                     1       0
#
#     B_avg_BODY_att  B_avg_BODY_landed  B_avg_CLINCH_att  B_avg_CLINCH_landed  \
# 4             17.0               14.5               2.5                  2.0
# 54             NaN                NaN               NaN                  NaN
# 60             8.0                8.0              15.0                 13.0
# 63             5.0                3.5               5.5                  3.5
# 69            35.0               21.0              38.0                 30.0
#
#     B_avg_DISTANCE_att  B_avg_DISTANCE_landed  ...    R_win_by_KO/TKO  \
# 4                201.0                   59.5  ...                  2
# 54                 NaN                    NaN  ...                  4
# 60                85.0                   38.0  ...                  0
# 63                16.0                    5.5  ...                  0
# 69               167.0                   69.0  ...                  9
#
#     R_win_by_Submission  R_win_by_TKO_Doctor_Stoppage  R_wins  R_Stance  \
# 4                     0                             0       3  Southpaw
# 54                    0                             0       4  Southpaw
# 60                    0                             0       2  Orthodox
# 63                    0                             0       0  Orthodox
# 69                    2                             0      16  Orthodox
#
#     R_Height_cms  R_Reach_cms  R_Weight_lbs  B_age  R_age
# 4         187.96       190.50         264.0   32.0   26.0
# 54        195.58       195.58         250.0   24.0   35.0
# 60        185.42       190.50         245.0   27.0   32.0
# 63        195.58       203.20         265.0   36.0   30.0
# 69        190.50       195.58         240.0   27.0   40.0
#
# [5 rows x 135 columns]

# %%
x=colunas
y=x

# %%
sns.set(style="ticks")
sns.pairplot(data_heavy_util, hue="origin", x_vars=x, y_vars=y)

# %% [markdown]
# ### Correlações

# %%
data_heavy_blue_winners = data_heavy.loc[(data_heavy.Winner==0),:]
data_heavy_blue_winners = data_heavy_blue_winners.drop(['Winner'], axis=1)
data_heavy_red_winners = data_heavy.loc[(data_heavy.Winner==1),:]
data_heavy_red_winners = data_heavy_red_winners.drop(['Winner'], axis=1)

# %%
blue_winners_correlation = data_heavy_blue_winners.corr()
blue_winners_correlation
# Out:
#                                   date  title_bout  no_of_rounds  \
# date                          1.000000   -0.161123     -0.032762
# title_bout                   -0.161123    1.000000      0.491461
# no_of_rounds                 -0.032762    0.491461      1.000000
# B_current_lose_streak         0.054294   -0.137166      0.197561
# B_current_win_streak         -0.145747    0.345926      0.187900
# B_draw                             NaN         NaN           NaN
# B_avg_BODY_att                0.274744    0.000122      0.074386
# B_avg_BODY_landed             0.256441    0.002365      0.052264
# B_avg_CLINCH_att              0.154872    0.059811      0.007436
# B_avg_CLINCH_landed           0.179436    0.056089     -0.003680
# B_avg_DISTANCE_att            0.355558    0.025759      0.074772
# B_avg_DISTANCE_landed         0.340451    0.057736      0.137432
# B_avg_GROUND_att             -0.210424    0.240572      0.027533
# B_avg_GROUND_landed          -0.153474    0.247515      0.008534
# B_avg_HEAD_att                0.276007    0.111454      0.077555
# B_avg_HEAD_landed             0.217758    0.199134      0.138383
# B_avg_KD                     -0.324659    0.176710      0.173811
# B_avg_LEG_att                 0.350873    0.028053      0.015772
# B_avg_LEG_landed              0.323243    0.055423      0.017389
# B_avg_PASS                   -0.197536    0.232970      0.021021
# B_avg_REV                    -0.199408   -0.072687     -0.082226
# B_avg_SIG_STR_att             0.318801    0.095368      0.079569
# B_avg_SIG_STR_landed          0.290758    0.154068      0.117629
# B_avg_SIG_STR_pct            -0.073649    0.132305      0.060434
# B_avg_SUB_ATT                -0.235467   -0.042834     -0.012485
# B_avg_TD_att                  0.039066    0.060800     -0.121389
# B_avg_TD_landed              -0.062157    0.076815     -0.071011
# B_avg_TD_pct                 -0.072528    0.102866      0.002063
# B_avg_TOTAL_STR_att           0.271987    0.194427      0.105675
# B_avg_TOTAL_STR_landed        0.192378    0.265170      0.132857
# ...                                ...         ...           ...
# R_avg_opp_HEAD_landed         0.203773   -0.141743     -0.056240
# R_avg_opp_KD                  0.097907   -0.149897     -0.011298
# R_avg_opp_LEG_att            -0.027968   -0.064946     -0.065168
# R_avg_opp_LEG_landed         -0.015462   -0.070575     -0.062338
# R_avg_opp_PASS                0.090032   -0.176749     -0.063892
# R_avg_opp_REV                -0.242255   -0.094002      0.029115
# R_avg_opp_SIG_STR_att         0.158532   -0.112770     -0.088357
# R_avg_opp_SIG_STR_landed      0.208601   -0.153761     -0.097370
# R_avg_opp_SIG_STR_pct         0.224468   -0.050713      0.040099
# R_avg_opp_SUB_ATT            -0.217706   -0.016353      0.022985
# R_avg_opp_TD_att              0.191752   -0.146565     -0.062595
# R_avg_opp_TD_landed           0.086688   -0.099625      0.056515
# R_avg_opp_TD_pct             -0.029792   -0.051889      0.046862
# R_avg_opp_TOTAL_STR_att       0.193881   -0.156854     -0.096248
# R_avg_opp_TOTAL_STR_landed    0.224013   -0.198175     -0.090846
# R_total_rounds_fought         0.332750    0.045132      0.229198
# R_total_time_fought(seconds)  0.116069   -0.048734      0.007183
# R_total_title_bouts           0.063531    0.281106      0.320054
# R_win_by_Decision_Majority    0.108041   -0.068455     -0.118108
# R_win_by_Decision_Split       0.231400   -0.082061      0.097086
# R_win_by_Decision_Unanimous   0.231107    0.198632      0.254201
# R_win_by_KO/TKO               0.255263    0.182796      0.301632
# R_win_by_Submission          -0.078268    0.064792      0.121706
# R_win_by_TKO_Doctor_Stoppage -0.051332   -0.056728      0.012118
# R_wins                        0.205434    0.181773      0.299674
# R_Height_cms                  0.029779   -0.018567      0.046856
# R_Reach_cms                   0.010070    0.100335      0.168529
# R_Weight_lbs                  0.050460   -0.185558      0.049829
# B_age                         0.102656    0.014377      0.330574
# R_age                         0.258130   -0.040564      0.089774
#
#                               B_current_lose_streak  B_current_win_streak  \
# date                                       0.054294             -0.145747
# title_bout                                -0.137166              0.345926
# no_of_rounds                               0.197561              0.187900
# B_current_lose_streak                      1.000000             -0.372420
# B_current_win_streak                      -0.372420              1.000000
# B_draw                                          NaN                   NaN
# B_avg_BODY_att                            -0.157427              0.091439
# B_avg_BODY_landed                         -0.157421              0.080253
# B_avg_CLINCH_att                          -0.037084             -0.048230
# B_avg_CLINCH_landed                       -0.058432             -0.055570
# B_avg_DISTANCE_att                        -0.125336              0.078090
# B_avg_DISTANCE_landed                     -0.172502              0.143041
# B_avg_GROUND_att                          -0.164758              0.104991
# B_avg_GROUND_landed                       -0.193524              0.123515
# B_avg_HEAD_att                            -0.151611              0.081988
# B_avg_HEAD_landed                         -0.225704              0.156615
# B_avg_KD                                  -0.121136              0.440891
# B_avg_LEG_att                             -0.114142              0.052223
# B_avg_LEG_landed                          -0.134274              0.056620
# B_avg_PASS                                -0.128312              0.002922
# B_avg_REV                                 -0.034596             -0.083607
# B_avg_SIG_STR_att                         -0.167302              0.090542
# B_avg_SIG_STR_landed                      -0.232495              0.146133
# B_avg_SIG_STR_pct                         -0.237346              0.263828
# B_avg_SUB_ATT                              0.073142             -0.098201
# B_avg_TD_att                              -0.086707             -0.097058
# B_avg_TD_landed                           -0.137759             -0.012337
# B_avg_TD_pct                              -0.107691             -0.028658
# B_avg_TOTAL_STR_att                       -0.203019              0.095036
# B_avg_TOTAL_STR_landed                    -0.239774              0.120768
# ...                                             ...                   ...
# R_avg_opp_HEAD_landed                      0.018623             -0.229697
# R_avg_opp_KD                               0.049208             -0.059303
# R_avg_opp_LEG_att                          0.002073             -0.115212
# R_avg_opp_LEG_landed                       0.018248             -0.125519
# R_avg_opp_PASS                             0.050205             -0.227744
# R_avg_opp_REV                              0.001150             -0.084447
# R_avg_opp_SIG_STR_att                      0.013386             -0.232372
# R_avg_opp_SIG_STR_landed                   0.042080             -0.254917
# R_avg_opp_SIG_STR_pct                      0.130261             -0.107136
# R_avg_opp_SUB_ATT                         -0.093644              0.030518
# R_avg_opp_TD_att                          -0.039171             -0.126583
# R_avg_opp_TD_landed                        0.010695             -0.122504
# R_avg_opp_TD_pct                           0.039822             -0.094548
# R_avg_opp_TOTAL_STR_att                    0.042951             -0.286796
# R_avg_opp_TOTAL_STR_landed                 0.068461             -0.303180
# R_total_rounds_fought                     -0.088860              0.263297
# R_total_time_fought(seconds)              -0.083635             -0.134844
# R_total_title_bouts                       -0.091400              0.310448
# R_win_by_Decision_Majority                 0.026349              0.043275
# R_win_by_Decision_Split                   -0.042957              0.051877
# R_win_by_Decision_Unanimous               -0.164409              0.196682
# R_win_by_KO/TKO                           -0.110859              0.400372
# R_win_by_Submission                        0.015331              0.109060
# R_win_by_TKO_Doctor_Stoppage               0.150660             -0.045517
# R_wins                                    -0.098475              0.351582
# R_Height_cms                               0.045668              0.015903
# R_Reach_cms                               -0.029027              0.152685
# R_Weight_lbs                               0.085575              0.149758
# B_age                                      0.228017              0.039346
# R_age                                     -0.107595              0.154148
#
#                               B_draw  B_avg_BODY_att  B_avg_BODY_landed  \
# date                             NaN        0.274744           0.256441
# title_bout                       NaN        0.000122           0.002365
# no_of_rounds                     NaN        0.074386           0.052264
# B_current_lose_streak            NaN       -0.157427          -0.157421
# B_current_win_streak             NaN        0.091439           0.080253
# B_draw                           NaN             NaN                NaN
# B_avg_BODY_att                   NaN        1.000000           0.970595
# B_avg_BODY_landed                NaN        0.970595           1.000000
# B_avg_CLINCH_att                 NaN        0.471033           0.453513
# B_avg_CLINCH_landed              NaN        0.484189           0.480466
# B_avg_DISTANCE_att               NaN        0.633079           0.562784
# B_avg_DISTANCE_landed            NaN        0.696099           0.637945
# B_avg_GROUND_att                 NaN        0.042282           0.097103
# B_avg_GROUND_landed              NaN        0.094738           0.155231
# B_avg_HEAD_att                   NaN        0.592429           0.535890
# B_avg_HEAD_landed                NaN        0.616507           0.570960
# B_avg_KD                         NaN        0.148970           0.121346
# B_avg_LEG_att                    NaN        0.308812           0.264817
# B_avg_LEG_landed                 NaN        0.293339           0.268782
# B_avg_PASS                       NaN       -0.110422          -0.073470
# B_avg_REV                        NaN       -0.167165          -0.152098
# B_avg_SIG_STR_att                NaN        0.708644           0.651467
# B_avg_SIG_STR_landed             NaN        0.776483           0.747608
# B_avg_SIG_STR_pct                NaN        0.213678           0.298217
# B_avg_SUB_ATT                    NaN       -0.246238          -0.229340
# B_avg_TD_att                     NaN       -0.140961          -0.101436
# B_avg_TD_landed                  NaN       -0.060566          -0.024977
# B_avg_TD_pct                     NaN        0.201838           0.192679
# B_avg_TOTAL_STR_att              NaN        0.631545           0.600835
# B_avg_TOTAL_STR_landed           NaN        0.560334           0.568540
# ...                              ...             ...                ...
# R_avg_opp_HEAD_landed            NaN        0.013181           0.018611
# R_avg_opp_KD                     NaN       -0.194460          -0.220548
# R_avg_opp_LEG_att                NaN       -0.050663          -0.022695
# R_avg_opp_LEG_landed             NaN       -0.042612          -0.013755
# R_avg_opp_PASS                   NaN        0.050227           0.047358
# R_avg_opp_REV                    NaN       -0.112163          -0.143398
# R_avg_opp_SIG_STR_att            NaN        0.030143           0.066016
# R_avg_opp_SIG_STR_landed         NaN        0.010192           0.035086
# R_avg_opp_SIG_STR_pct            NaN       -0.005772          -0.036405
# R_avg_opp_SUB_ATT                NaN       -0.075683          -0.103339
# R_avg_opp_TD_att                 NaN        0.027238           0.020611
# R_avg_opp_TD_landed              NaN        0.013951          -0.001199
# R_avg_opp_TD_pct                 NaN       -0.081317          -0.098752
# R_avg_opp_TOTAL_STR_att          NaN        0.009247           0.053441
# R_avg_opp_TOTAL_STR_landed       NaN       -0.006195           0.034332
# R_total_rounds_fought            NaN        0.251343           0.233839
# R_total_time_fought(seconds)     NaN        0.050358           0.094498
# R_total_title_bouts              NaN        0.260603           0.275299
# R_win_by_Decision_Majority       NaN       -0.105000          -0.128851
# R_win_by_Decision_Split          NaN        0.184398           0.139895
# R_win_by_Decision_Unanimous      NaN        0.244045           0.245352
# R_win_by_KO/TKO                  NaN        0.257081           0.244604
# R_win_by_Submission              NaN        0.036723           0.047206
# R_win_by_TKO_Doctor_Stoppage     NaN       -0.155212          -0.170191
# R_wins                           NaN        0.242334           0.234113
# R_Height_cms                     NaN       -0.099444          -0.144853
# R_Reach_cms                      NaN       -0.052242          -0.085336
# R_Weight_lbs                     NaN       -0.105444          -0.107734
# B_age                            NaN       -0.183091          -0.179223
# R_age                            NaN        0.149032           0.165927
#
#                               B_avg_CLINCH_att  B_avg_CLINCH_landed    ...     \
# date                                  0.154872             0.179436    ...
# title_bout                            0.059811             0.056089    ...
# no_of_rounds                          0.007436            -0.003680    ...
# B_current_lose_streak                -0.037084            -0.058432    ...
# B_current_win_streak                 -0.048230            -0.055570    ...
# B_draw                                     NaN                  NaN    ...
# B_avg_BODY_att                        0.471033             0.484189    ...
# B_avg_BODY_landed                     0.453513             0.480466    ...
# B_avg_CLINCH_att                      1.000000             0.982379    ...
# B_avg_CLINCH_landed                   0.982379             1.000000    ...
# B_avg_DISTANCE_att                    0.239676             0.215990    ...
# B_avg_DISTANCE_landed                 0.314574             0.290996    ...
# B_avg_GROUND_att                     -0.011663             0.011003    ...
# B_avg_GROUND_landed                   0.022880             0.048116    ...
# B_avg_HEAD_att                        0.373269             0.347295    ...
# B_avg_HEAD_landed                     0.573683             0.557901    ...
# B_avg_KD                             -0.028284            -0.050062    ...
# B_avg_LEG_att                         0.269173             0.255851    ...
# B_avg_LEG_landed                      0.258276             0.249328    ...
# B_avg_PASS                           -0.078028            -0.052850    ...
# B_avg_REV                            -0.230502            -0.210009    ...
# B_avg_SIG_STR_att                     0.425857             0.405274    ...
# B_avg_SIG_STR_landed                  0.590666             0.585392    ...
# B_avg_SIG_STR_pct                     0.369790             0.415669    ...
# B_avg_SUB_ATT                         0.055326             0.069628    ...
# B_avg_TD_att                         -0.039461            -0.032300    ...
# B_avg_TD_landed                      -0.066313            -0.049852    ...
# B_avg_TD_pct                          0.150500             0.172043    ...
# B_avg_TOTAL_STR_att                   0.477432             0.469943    ...
# B_avg_TOTAL_STR_landed                0.576695             0.589252    ...
# ...                                        ...                  ...    ...
# R_avg_opp_HEAD_landed                 0.145701             0.146789    ...
# R_avg_opp_KD                         -0.092588            -0.113296    ...
# R_avg_opp_LEG_att                     0.072812             0.052223    ...
# R_avg_opp_LEG_landed                  0.074936             0.056320    ...
# R_avg_opp_PASS                       -0.164653            -0.154745    ...
# R_avg_opp_REV                        -0.106751            -0.129254    ...
# R_avg_opp_SIG_STR_att                 0.288954             0.290031    ...
# R_avg_opp_SIG_STR_landed              0.150044             0.143163    ...
# R_avg_opp_SIG_STR_pct                -0.172862            -0.189226    ...
# R_avg_opp_SUB_ATT                    -0.111317            -0.131424    ...
# R_avg_opp_TD_att                      0.005523             0.008225    ...
# R_avg_opp_TD_landed                  -0.024958            -0.032912    ...
# R_avg_opp_TD_pct                      0.027172             0.008105    ...
# R_avg_opp_TOTAL_STR_att               0.243828             0.246643    ...
# R_avg_opp_TOTAL_STR_landed            0.121445             0.115928    ...
# R_total_rounds_fought                 0.313837             0.321320    ...
# R_total_time_fought(seconds)          0.254912             0.258497    ...
# R_total_title_bouts                   0.321371             0.349054    ...
# R_win_by_Decision_Majority           -0.026207            -0.031697    ...
# R_win_by_Decision_Split               0.155977             0.185492    ...
# R_win_by_Decision_Unanimous           0.314549             0.321567    ...
# R_win_by_KO/TKO                       0.186891             0.208670    ...
# R_win_by_Submission                   0.111182             0.112880    ...
# R_win_by_TKO_Doctor_Stoppage          0.015858            -0.035587    ...
# R_wins                                0.257541             0.273482    ...
# R_Height_cms                         -0.048828            -0.056125    ...
# R_Reach_cms                          -0.076047            -0.069099    ...
# R_Weight_lbs                         -0.243397            -0.241425    ...
# B_age                                -0.202556            -0.191275    ...
# R_age                                 0.210127             0.196265    ...
#
#                               R_win_by_Decision_Unanimous  R_win_by_KO/TKO  \
# date                                             0.231107         0.255263
# title_bout                                       0.198632         0.182796
# no_of_rounds                                     0.254201         0.301632
# B_current_lose_streak                           -0.164409        -0.110859
# B_current_win_streak                             0.196682         0.400372
# B_draw                                                NaN              NaN
# B_avg_BODY_att                                   0.244045         0.257081
# B_avg_BODY_landed                                0.245352         0.244604
# B_avg_CLINCH_att                                 0.314549         0.186891
# B_avg_CLINCH_landed                              0.321567         0.208670
# B_avg_DISTANCE_att                               0.159828         0.123301
# B_avg_DISTANCE_landed                            0.258624         0.211454
# B_avg_GROUND_att                                 0.033180         0.095936
# B_avg_GROUND_landed                              0.045460         0.128434
# B_avg_HEAD_att                                   0.194429         0.152266
# B_avg_HEAD_landed                                0.338536         0.298237
# B_avg_KD                                        -0.029926         0.164447
# B_avg_LEG_att                                    0.157257         0.047511
# B_avg_LEG_landed                                 0.129736         0.034923
# B_avg_PASS                                       0.035131         0.094550
# B_avg_REV                                       -0.069512        -0.074059
# B_avg_SIG_STR_att                                0.223536         0.178494
# B_avg_SIG_STR_landed                             0.337899         0.290923
# B_avg_SIG_STR_pct                                0.265053         0.341924
# B_avg_SUB_ATT                                   -0.051472        -0.120391
# B_avg_TD_att                                     0.067526        -0.069825
# B_avg_TD_landed                                  0.003335         0.000462
# B_avg_TD_pct                                     0.111990         0.183394
# B_avg_TOTAL_STR_att                              0.236352         0.202535
# B_avg_TOTAL_STR_landed                           0.293837         0.270051
# ...                                                   ...              ...
# R_avg_opp_HEAD_landed                           -0.021692        -0.084678
# R_avg_opp_KD                                     0.002135        -0.087549
# R_avg_opp_LEG_att                                0.052588        -0.085320
# R_avg_opp_LEG_landed                             0.048987        -0.079155
# R_avg_opp_PASS                                  -0.194147        -0.085465
# R_avg_opp_REV                                    0.009332        -0.113382
# R_avg_opp_SIG_STR_att                            0.068517        -0.099813
# R_avg_opp_SIG_STR_landed                        -0.027972        -0.099940
# R_avg_opp_SIG_STR_pct                           -0.174301        -0.132315
# R_avg_opp_SUB_ATT                               -0.032256        -0.067260
# R_avg_opp_TD_att                                 0.032647         0.226377
# R_avg_opp_TD_landed                             -0.103553         0.080369
# R_avg_opp_TD_pct                                -0.138592        -0.136276
# R_avg_opp_TOTAL_STR_att                          0.028028        -0.137389
# R_avg_opp_TOTAL_STR_landed                      -0.059176        -0.138599
# R_total_rounds_fought                            0.671874         0.852305
# R_total_time_fought(seconds)                     0.276996        -0.026541
# R_total_title_bouts                              0.670661         0.606940
# R_win_by_Decision_Majority                      -0.064994         0.041507
# R_win_by_Decision_Split                          0.393559         0.492270
# R_win_by_Decision_Unanimous                      1.000000         0.478612
# R_win_by_KO/TKO                                  0.478612         1.000000
# R_win_by_Submission                              0.262338         0.186762
# R_win_by_TKO_Doctor_Stoppage                    -0.013120        -0.047675
# R_wins                                           0.672221         0.860184
# R_Height_cms                                     0.088059        -0.014308
# R_Reach_cms                                      0.062226         0.003483
# R_Weight_lbs                                    -0.097041         0.058325
# B_age                                            0.190206         0.319185
# R_age                                            0.245523         0.383716
#
#                               R_win_by_Submission  \
# date                                    -0.078268
# title_bout                               0.064792
# no_of_rounds                             0.121706
# B_current_lose_streak                    0.015331
# B_current_win_streak                     0.109060
# B_draw                                        NaN
# B_avg_BODY_att                           0.036723
# B_avg_BODY_landed                        0.047206
# B_avg_CLINCH_att                         0.111182
# B_avg_CLINCH_landed                      0.112880
# B_avg_DISTANCE_att                      -0.100281
# B_avg_DISTANCE_landed                   -0.071332
# B_avg_GROUND_att                         0.097037
# B_avg_GROUND_landed                      0.091139
# B_avg_HEAD_att                          -0.067292
# B_avg_HEAD_landed                       -0.002833
# B_avg_KD                                 0.155563
# B_avg_LEG_att                           -0.007327
# B_avg_LEG_landed                        -0.015982
# B_avg_PASS                               0.002398
# B_avg_REV                               -0.120539
# B_avg_SIG_STR_att                       -0.049725
# B_avg_SIG_STR_landed                     0.008516
# B_avg_SIG_STR_pct                        0.184412
# B_avg_SUB_ATT                           -0.032439
# B_avg_TD_att                            -0.148076
# B_avg_TD_landed                         -0.098279
# B_avg_TD_pct                             0.093003
# B_avg_TOTAL_STR_att                     -0.043864
# B_avg_TOTAL_STR_landed                   0.008374
# ...                                           ...
# R_avg_opp_HEAD_landed                   -0.126274
# R_avg_opp_KD                            -0.011049
# R_avg_opp_LEG_att                       -0.086265
# R_avg_opp_LEG_landed                    -0.076094
# R_avg_opp_PASS                          -0.118463
# R_avg_opp_REV                            0.094701
# R_avg_opp_SIG_STR_att                   -0.190641
# R_avg_opp_SIG_STR_landed                -0.144128
# R_avg_opp_SIG_STR_pct                    0.117134
# R_avg_opp_SUB_ATT                       -0.070925
# R_avg_opp_TD_att                        -0.203468
# R_avg_opp_TD_landed                     -0.077192
# R_avg_opp_TD_pct                         0.143375
# R_avg_opp_TOTAL_STR_att                 -0.197130
# R_avg_opp_TOTAL_STR_landed              -0.142079
# R_total_rounds_fought                    0.430686
# R_total_time_fought(seconds)            -0.210130
# R_total_title_bouts                      0.514132
# R_win_by_Decision_Majority               0.098861
# R_win_by_Decision_Split                  0.064026
# R_win_by_Decision_Unanimous              0.262338
# R_win_by_KO/TKO                          0.186762
# R_win_by_Submission                      1.000000
# R_win_by_TKO_Doctor_Stoppage            -0.031068
# R_wins                                   0.607189
# R_Height_cms                             0.311161
# R_Reach_cms                              0.329661
# R_Weight_lbs                             0.117435
# B_age                                    0.228201
# R_age                                    0.022672
#
#                               R_win_by_TKO_Doctor_Stoppage    R_wins  \
# date                                             -0.051332  0.205434
# title_bout                                       -0.056728  0.181773
# no_of_rounds                                      0.012118  0.299674
# B_current_lose_streak                             0.150660 -0.098475
# B_current_win_streak                             -0.045517  0.351582
# B_draw                                                 NaN       NaN
# B_avg_BODY_att                                   -0.155212  0.242334
# B_avg_BODY_landed                                -0.170191  0.234113
# B_avg_CLINCH_att                                  0.015858  0.257541
# B_avg_CLINCH_landed                              -0.035587  0.273482
# B_avg_DISTANCE_att                               -0.022741  0.078854
# B_avg_DISTANCE_landed                            -0.047931  0.169354
# B_avg_GROUND_att                                 -0.058975  0.120590
# B_avg_GROUND_landed                              -0.076071  0.143951
# B_avg_HEAD_att                                    0.019953  0.127429
# B_avg_HEAD_landed                                 0.006804  0.289645
# B_avg_KD                                          0.045652  0.164749
# B_avg_LEG_att                                    -0.182799  0.056088
# B_avg_LEG_landed                                 -0.184716  0.035588
# B_avg_PASS                                       -0.109770  0.072867
# B_avg_REV                                        -0.032986 -0.117786
# B_avg_SIG_STR_att                                -0.032949  0.156240
# B_avg_SIG_STR_landed                             -0.078719  0.281867
# B_avg_SIG_STR_pct                                -0.046286  0.370222
# B_avg_SUB_ATT                                    -0.109616 -0.118781
# B_avg_TD_att                                     -0.072387 -0.075035
# B_avg_TD_landed                                  -0.139854 -0.023331
# B_avg_TD_pct                                     -0.169905  0.197672
# B_avg_TOTAL_STR_att                              -0.099552  0.181405
# B_avg_TOTAL_STR_landed                           -0.155517  0.261835
# ...                                                    ...       ...
# R_avg_opp_HEAD_landed                            -0.046415 -0.129271
# R_avg_opp_KD                                      0.036120 -0.071346
# R_avg_opp_LEG_att                                 0.043176 -0.086739
# R_avg_opp_LEG_landed                              0.047061 -0.078672
# R_avg_opp_PASS                                   -0.106847 -0.138162
# R_avg_opp_REV                                     0.052744 -0.029525
# R_avg_opp_SIG_STR_att                             0.031496 -0.134838
# R_avg_opp_SIG_STR_landed                         -0.004371 -0.139895
# R_avg_opp_SIG_STR_pct                            -0.080791 -0.089553
# R_avg_opp_SUB_ATT                                -0.116214 -0.077497
# R_avg_opp_TD_att                                  0.053529  0.085335
# R_avg_opp_TD_landed                               0.000980  0.011696
# R_avg_opp_TD_pct                                 -0.054209 -0.046954
# R_avg_opp_TOTAL_STR_att                           0.032008 -0.168252
# R_avg_opp_TOTAL_STR_landed                        0.013066 -0.164455
# R_total_rounds_fought                             0.011992  0.922279
# R_total_time_fought(seconds)                      0.110241 -0.029021
# R_total_title_bouts                              -0.093937  0.779099
# R_win_by_Decision_Majority                       -0.053395  0.115901
# R_win_by_Decision_Split                          -0.064008  0.487167
# R_win_by_Decision_Unanimous                      -0.013120  0.672221
# R_win_by_KO/TKO                                  -0.047675  0.860184
# R_win_by_Submission                              -0.031068  0.607189
# R_win_by_TKO_Doctor_Stoppage                      1.000000 -0.009874
# R_wins                                           -0.009874  1.000000
# R_Height_cms                                     -0.016592  0.149661
# R_Reach_cms                                      -0.044533  0.160303
# R_Weight_lbs                                     -0.042307  0.070002
# B_age                                            -0.009052  0.344284
# R_age                                             0.010362  0.319350
#
#                               R_Height_cms  R_Reach_cms  R_Weight_lbs  \
# date                              0.029779     0.010070      0.050460
# title_bout                       -0.018567     0.100335     -0.185558
# no_of_rounds                      0.046856     0.168529      0.049829
# B_current_lose_streak             0.045668    -0.029027      0.085575
# B_current_win_streak              0.015903     0.152685      0.149758
# B_draw                                 NaN          NaN           NaN
# B_avg_BODY_att                   -0.099444    -0.052242     -0.105444
# B_avg_BODY_landed                -0.144853    -0.085336     -0.107734
# B_avg_CLINCH_att                 -0.048828    -0.076047     -0.243397
# B_avg_CLINCH_landed              -0.056125    -0.069099     -0.241425
# B_avg_DISTANCE_att               -0.086478    -0.109509     -0.123207
# B_avg_DISTANCE_landed            -0.127865    -0.137589     -0.192738
# B_avg_GROUND_att                  0.021285     0.135164      0.103111
# B_avg_GROUND_landed              -0.017733     0.110672      0.080947
# B_avg_HEAD_att                   -0.087086    -0.095057     -0.122196
# B_avg_HEAD_landed                -0.123010    -0.104043     -0.201557
# B_avg_KD                         -0.029446     0.068188      0.046747
# B_avg_LEG_att                     0.027540     0.012567     -0.180328
# B_avg_LEG_landed                 -0.011868    -0.000868     -0.192807
# B_avg_PASS                        0.075401     0.160288      0.117288
# B_avg_REV                        -0.089343    -0.032457      0.022956
# B_avg_SIG_STR_att                -0.087080    -0.086698     -0.141035
# B_avg_SIG_STR_landed             -0.132141    -0.099279     -0.211898
# B_avg_SIG_STR_pct                -0.087806     0.026588     -0.044372
# B_avg_SUB_ATT                     0.124875     0.137972      0.120453
# B_avg_TD_att                     -0.144447    -0.104508     -0.080681
# B_avg_TD_landed                  -0.109327    -0.021169      0.057664
# B_avg_TD_pct                     -0.024167     0.040892      0.098430
# B_avg_TOTAL_STR_att              -0.048349    -0.022641     -0.124249
# B_avg_TOTAL_STR_landed           -0.048603     0.007089     -0.150967
# ...                                    ...          ...           ...
# R_avg_opp_HEAD_landed            -0.190077    -0.190989     -0.290682
# R_avg_opp_KD                      0.031948     0.077051     -0.193101
# R_avg_opp_LEG_att                -0.152606    -0.209936     -0.444074
# R_avg_opp_LEG_landed             -0.175238    -0.234520     -0.459454
# R_avg_opp_PASS                   -0.206614    -0.189810     -0.032384
# R_avg_opp_REV                     0.155641     0.120905      0.036151
# R_avg_opp_SIG_STR_att            -0.286915    -0.338838     -0.466824
# R_avg_opp_SIG_STR_landed         -0.249879    -0.275730     -0.360471
# R_avg_opp_SIG_STR_pct             0.164357     0.183278      0.187492
# R_avg_opp_SUB_ATT                 0.152334     0.156246      0.127681
# R_avg_opp_TD_att                 -0.145909    -0.207963     -0.086799
# R_avg_opp_TD_landed              -0.080349    -0.117998      0.117967
# R_avg_opp_TD_pct                  0.186121     0.124550      0.128990
# R_avg_opp_TOTAL_STR_att          -0.315511    -0.366757     -0.392469
# R_avg_opp_TOTAL_STR_landed       -0.278487    -0.294028     -0.229755
# R_total_rounds_fought             0.024378    -0.008422      0.037099
# R_total_time_fought(seconds)     -0.155250    -0.252965     -0.219969
# R_total_title_bouts               0.000783     0.117671     -0.012617
# R_win_by_Decision_Majority        0.244755     0.186781      0.128457
# R_win_by_Decision_Split          -0.011794    -0.012940     -0.052082
# R_win_by_Decision_Unanimous       0.088059     0.062226     -0.097041
# R_win_by_KO/TKO                  -0.014308     0.003483      0.058325
# R_win_by_Submission               0.311161     0.329661      0.117435
# R_win_by_TKO_Doctor_Stoppage     -0.016592    -0.044533     -0.042307
# R_wins                            0.149661     0.160303      0.070002
# R_Height_cms                      1.000000     0.786656      0.293325
# R_Reach_cms                       0.786656     1.000000      0.235046
# R_Weight_lbs                      0.293325     0.235046      1.000000
# B_age                             0.072726     0.064883      0.077560
# R_age                            -0.345274    -0.245606     -0.068451
#
#                                  B_age     R_age
# date                          0.102656  0.258130
# title_bout                    0.014377 -0.040564
# no_of_rounds                  0.330574  0.089774
# B_current_lose_streak         0.228017 -0.107595
# B_current_win_streak          0.039346  0.154148
# B_draw                             NaN       NaN
# B_avg_BODY_att               -0.183091  0.149032
# B_avg_BODY_landed            -0.179223  0.165927
# B_avg_CLINCH_att             -0.202556  0.210127
# B_avg_CLINCH_landed          -0.191275  0.196265
# B_avg_DISTANCE_att           -0.215869  0.071484
# B_avg_DISTANCE_landed        -0.180228  0.158372
# B_avg_GROUND_att             -0.241699  0.079454
# B_avg_GROUND_landed          -0.250088  0.116911
# B_avg_HEAD_att               -0.315375  0.101284
# B_avg_HEAD_landed            -0.315929  0.219477
# B_avg_KD                      0.093824 -0.008020
# B_avg_LEG_att                -0.098588  0.162168
# B_avg_LEG_landed             -0.125536  0.174966
# B_avg_PASS                   -0.109983 -0.025839
# B_avg_REV                     0.003830 -0.172124
# B_avg_SIG_STR_att            -0.305599  0.129666
# B_avg_SIG_STR_landed         -0.301889  0.238119
# B_avg_SIG_STR_pct            -0.096723  0.196158
# B_avg_SUB_ATT                -0.035806 -0.228075
# B_avg_TD_att                 -0.086521  0.048445
# B_avg_TD_landed              -0.146760  0.001422
# B_avg_TD_pct                 -0.173090  0.126484
# B_avg_TOTAL_STR_att          -0.325520  0.119101
# B_avg_TOTAL_STR_landed       -0.286816  0.169042
# ...                                ...       ...
# R_avg_opp_HEAD_landed        -0.002466  0.097507
# R_avg_opp_KD                  0.051081  0.140992
# R_avg_opp_LEG_att             0.025707  0.060520
# R_avg_opp_LEG_landed          0.035868  0.045392
# R_avg_opp_PASS                0.021722  0.013591
# R_avg_opp_REV                 0.013431 -0.022159
# R_avg_opp_SIG_STR_att        -0.036001  0.060848
# R_avg_opp_SIG_STR_landed      0.010319  0.088682
# R_avg_opp_SIG_STR_pct         0.104543  0.081044
# R_avg_opp_SUB_ATT            -0.063308 -0.175583
# R_avg_opp_TD_att              0.125456  0.076805
# R_avg_opp_TD_landed           0.090337  0.061966
# R_avg_opp_TD_pct             -0.056219  0.042259
# R_avg_opp_TOTAL_STR_att      -0.046878  0.056587
# R_avg_opp_TOTAL_STR_landed   -0.016012  0.076725
# R_total_rounds_fought         0.306096  0.461145
# R_total_time_fought(seconds)  0.002103 -0.030445
# R_total_title_bouts           0.180421  0.329017
# R_win_by_Decision_Majority   -0.033941 -0.088866
# R_win_by_Decision_Split       0.083480  0.183766
# R_win_by_Decision_Unanimous   0.190206  0.245523
# R_win_by_KO/TKO               0.319185  0.383716
# R_win_by_Submission           0.228201  0.022672
# R_win_by_TKO_Doctor_Stoppage -0.009052  0.010362
# R_wins                        0.344284  0.319350
# R_Height_cms                  0.072726 -0.345274
# R_Reach_cms                   0.064883 -0.245606
# R_Weight_lbs                  0.077560 -0.068451
# B_age                         1.000000  0.027200
# R_age                         0.027200  1.000000
#
# [137 rows x 137 columns]

# %% [markdown]
# ### Aplicando filtros

# %%
filtros = ['R_fighter','B_fighter','Winner','weight_class','title_bout','R_wins','R_losses','B_wins','B_losses',
           'B_Reach_cms','B_Height_cms','B_Weight_lbs','R_Reach_cms','R_Height_cms','R_Weight_lbs']

# %%
data_heavy_filtered = data_heavy.loc[:,filtros]

# %%
data_heavy_filtered.head()
# Out:
#           R_fighter          B_fighter  Winner weight_class  title_bout  \
# 4       Tai Tuivasa      Blagoy Ivanov       0  Heavyweight           0
# 54      Walt Harris     Serghei Spivac       1  Heavyweight           0
# 60    Arjan Bhullar         Juan Adams       1  Heavyweight           0
# 63       Greg Hardy  Dmitrii Smoliakov       1  Heavyweight           0
# 69  Andrei Arlovski      Augusto Sakai       0  Heavyweight           0
#
#     R_wins  R_losses  B_wins  B_losses  B_Reach_cms  B_Height_cms  \
# 4        3         1       1         1       185.42        180.34
# 54       4         7       0         0       198.12        190.50
# 60       2         1       1         0       203.20        195.58
# 63       0         1       0         2       187.96        187.96
# 69      16        12       1         0       195.58        190.50
#
#     B_Weight_lbs  R_Reach_cms  R_Height_cms  R_Weight_lbs
# 4          250.0       190.50        187.96         264.0
# 54         260.0       195.58        195.58         250.0
# 60         265.0       190.50        185.42         245.0
# 63         253.0       203.20        195.58         265.0
# 69         265.0       195.58        190.50         240.0

# %%
data_heavy_filtered['B_Reach_cms'].corr(data_heavy_filtered['Winner'])
# Out:
# -0.1090621360814943

# %%
data_heavy_util=data_heavy_util.dropna()
for nome_col in colunas:
    #c=data_heavy_util[colunas[i]].corr(data_heavy_util['Winner'])
    c=data_heavy_util[nome_col].corr(data_heavy_util['Winner'])
    print(c)
    if c<0.05 and c>0:
        data_heavy_util.drop(nome_col,axis=1)  
    elif  c<0 and c>-0.05:
        data_heavy_util.drop(nome_col,axis=1)
# Out:
# 1.0
# -0.027342948953226653
# -0.04828682669155675
# nan
# -0.16603794298259608
# -0.16559627693779944
# -0.0697719647024303
# -0.06763805063917308
# -0.1463959996954793
# -0.12671746572970893
# -0.016733414582464478
# -0.026687437548784727
# -0.1453054067778058
# -0.11133382962779527
# 0.07122980292334141
# -0.020577844342641788
# -0.020490664663967716
# 0.04017253694796535
# 0.1214035354297481
# -0.1550384078186563
# -0.1346367476122478
# -0.08843797172482522
# 0.06194430584400583
# -0.04206378201932684
# -0.027842599636433603
# 0.029911312911948335
# -0.13953164008759802
# -0.10517653252438368
# -0.019017127976364498
# 0.07740828475410316
# -0.06247875663489411
# -0.04077235673989077
# -0.029993908422933563
# -0.018489961877842243
# -0.07991477644154811
# -0.052751962060009955
# 0.08146636096288215
# 0.08366109134199903
# -0.054858780721967364
# -0.011120779001125129
# 0.08563158143826338
# -0.037321285650113785
# -0.013319848497432151
# 0.057591172903410495
# 0.05113637144960403
# -0.06311866826629027
# -0.02381251002248239
# 0.01877116466321957
# 0.016581698915309508
# -0.021899251656686627
# 0.026795953879838817
# 0.10358859283877622
# -0.02924174219713082
# 0.020104350564892768
# -0.08675623726907675
# 0.049279809085302786
# 0.08904433969220751
# -0.10770877355021254
# -0.06890946730440892
# 0.03273426655452903
# 0.06309548452191674
# -0.022693901612302496
# 0.02657807095728214
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-04520e3da0e1> in <module>
#       2 for nome_col in colunas:
#       3     #c=data_heavy_util[colunas[i]].corr(data_heavy_util['Winner'])
# ----> 4     c=data_heavy_util[nome_col].corr(data_heavy_util['Winner'])
#       5     print(c)
#       6     if c<0.05 and c>0:
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in corr(self, other, method, min_periods)
#    1909             return np.nan
#    1910         return nanops.nancorr(this.values, other.values, method=method,
# -> 1911                               min_periods=min_periods)
#    1912
#    1913     def cov(self, other, min_periods=None):
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      75             try:
#      76                 with np.errstate(invalid='ignore'):
# ---> 77                     return f(*args, **kwargs)
#      78             except ValueError as e:
#      79                 # we want to transform an object array
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in nancorr(a, b, method, min_periods)
#     760
#     761     f = get_corr_func(method)
# --> 762     return f(a, b)
#     763
#     764
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in _pearson(a, b)
#     768
#     769     def _pearson(a, b):
# --> 770         return np.corrcoef(a, b)[0, 1]
#     771
#     772     def _kendall(a, b):
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in corrcoef(x, y, rowvar, bias, ddof)
#    2390         warnings.warn('bias and ddof have no effect and are deprecated',
#    2391                       DeprecationWarning, stacklevel=2)
# -> 2392     c = cov(x, y, rowvar)
#    2393     try:
#    2394         d = diag(c)
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights)
#    2300             w *= aweights
#    2301
# -> 2302     avg, w_sum = average(X, axis=1, weights=w, returned=True)
#    2303     w_sum = w_sum[0]
#    2304
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in average(a, axis, weights, returned)
#     354
#     355     if weights is None:
# --> 356         avg = a.mean(axis)
#     357         scl = avg.dtype.type(a.size/avg.size)
#     358     else:
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#      76     if isinstance(ret, mu.ndarray):
#      77         ret = um.true_divide(
# ---> 78                 ret, rcount, out=ret, casting='unsafe', subok=False)
#      79         if is_float16_result and out is None:
#      80             ret = arr.dtype.type(ret)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
