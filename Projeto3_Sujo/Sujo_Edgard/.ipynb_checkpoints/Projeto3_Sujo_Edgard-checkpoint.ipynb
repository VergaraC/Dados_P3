# %%
import math
import os.path
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import json
import random
import statsmodels.api as sm
import seaborn as sns

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import MultinomialNB

from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
data = pd.read_excel("data.xlsx")
data.head()
# Out:
#               R_fighter       B_fighter          Referee  date  \
# 0          Henry Cejudo   Marlon Moraes     Marc Goddard  2019
# 1  Valentina Shevchenko     Jessica Eye  Robert Madrigal  2019
# 2         Tony Ferguson  Donald Cerrone  Dan Miragliotta  2019
# 3         Jimmie Rivera        Petr Yan  Kevin MacDonald  2019
# 4           Tai Tuivasa   Blagoy Ivanov  Dan Miragliotta  2019
#
#                  location Winner  title_bout       weight_class  no_of_rounds  \
# 0  Chicago, Illinois, USA    Red        True       Bantamweight             5
# 1  Chicago, Illinois, USA    Red        True  Women's Flyweight             5
# 2  Chicago, Illinois, USA    Red       False        Lightweight             3
# 3  Chicago, Illinois, USA   Blue       False       Bantamweight             3
# 4  Chicago, Illinois, USA   Blue       False        Heavyweight             3
#
#    B_current_lose_streak  ...    R_win_by_KO/TKO  R_win_by_Submission  \
# 0                      0  ...                  2                    0
# 1                      0  ...                  0                    2
# 2                      0  ...                  3                    6
# 3                      0  ...                  1                    0
# 4                      0  ...                  2                    0
#
#    R_win_by_TKO_Doctor_Stoppage  R_wins  R_Stance  R_Height_cms  R_Reach_cms  \
# 0                             0       8  Orthodox        162.56       162.56
# 1                             0       5  Southpaw        165.10       167.64
# 2                             1      14  Orthodox        180.34       193.04
# 3                             0       6  Orthodox        162.56       172.72
# 4                             0       3  Southpaw        187.96       190.50
#
#    R_Weight_lbs  B_age  R_age
# 0         135.0   31.0   32.0
# 1         125.0   32.0   31.0
# 2         155.0   36.0   35.0
# 3         135.0   26.0   29.0
# 4         264.0   32.0   26.0
#
# [5 rows x 145 columns]

# %% [markdown]
# ### Apenas a categoria Peso-Pesados ('Heavyweights')

# %%
data.weight_class = data.weight_class.astype('category')
data.Winner = data.Winner.astype('category')

# %%
data.Winner.value_counts()
# Out:
# Red     3470
# Blue    1591
# Draw      83
# Name: Winner, dtype: int64

# %% [markdown]
# ### Blue = 0
# ### Red = 1

# %%
data_heavy = data.loc[(data.weight_class=='Heavyweight'),:]
bool_to_number = {False: 0, True: 1}
string_to_number = {'Blue': 0, 'Red': 1, 'Draw': 2}
data_heavy['title_bout'] = data_heavy['title_bout'].map(bool_to_number)
data_heavy['Winner'] = data_heavy['Winner'].map(string_to_number)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
data_heavy_util = data_heavy.drop(['Referee','date','location'], axis=1)
data_heavy_util.dropna(inplace=True)

# %%
data_heavy_util.head()
# Out:
#            R_fighter          B_fighter  Winner  title_bout weight_class  \
# 4        Tai Tuivasa      Blagoy Ivanov       0           0  Heavyweight
# 60     Arjan Bhullar         Juan Adams       1           0  Heavyweight
# 63        Greg Hardy  Dmitrii Smoliakov       1           0  Heavyweight
# 69   Andrei Arlovski      Augusto Sakai       0           0  Heavyweight
# 75  Alistair Overeem    Aleksei Oleinik       1           0  Heavyweight
#
#     no_of_rounds  B_current_lose_streak  B_current_win_streak  B_draw  \
# 4              3                      0                     1       0
# 60             3                      0                     1       0
# 63             3                      2                     0       0
# 69             3                      0                     1       0
# 75             5                      0                     2       0
#
#     B_avg_BODY_att  ...    R_win_by_KO/TKO  R_win_by_Submission  \
# 4            17.00  ...                  2                    0
# 60            8.00  ...                  0                    0
# 63            5.00  ...                  0                    0
# 69           35.00  ...                  9                    2
# 75            4.25  ...                  6                    0
#
#     R_win_by_TKO_Doctor_Stoppage  R_wins  R_Stance  R_Height_cms  R_Reach_cms  \
# 4                              0       3  Southpaw        187.96       190.50
# 60                             0       2  Orthodox        185.42       190.50
# 63                             0       0  Orthodox        195.58       203.20
# 69                             0      16  Orthodox        190.50       195.58
# 75                             0       9  Orthodox        193.04       203.20
#
#     R_Weight_lbs  B_age  R_age
# 4          264.0   32.0   26.0
# 60         245.0   27.0   32.0
# 63         265.0   36.0   30.0
# 69         240.0   27.0   40.0
# 75         265.0   41.0   38.0
#
# [5 rows x 142 columns]

# %%
colunas = list(data_heavy_util)

# %%
colunas.remove('R_fighter')
colunas.remove('B_fighter')
colunas.remove('title_bout')
colunas.remove('weight_class')
colunas.remove('no_of_rounds')
colunas.remove('B_total_rounds_fought')
colunas.remove('R_total_rounds_fought')

# %%
dataf = data_heavy_util.loc[:,colunas]
dataf.head()
# Out:
#     Winner  B_current_lose_streak  B_current_win_streak  B_draw  \
# 4        0                      0                     1       0
# 60       1                      0                     1       0
# 63       1                      2                     0       0
# 69       0                      0                     1       0
# 75       1                      0                     2       0
#
#     B_avg_BODY_att  B_avg_BODY_landed  B_avg_CLINCH_att  B_avg_CLINCH_landed  \
# 4            17.00             14.500             2.500                2.000
# 60            8.00              8.000            15.000               13.000
# 63            5.00              3.500             5.500                3.500
# 69           35.00             21.000            38.000               30.000
# 75            4.25              3.875             5.375                4.125
#
#     B_avg_DISTANCE_att  B_avg_DISTANCE_landed  ...    R_win_by_KO/TKO  \
# 4              201.000                   59.5  ...                  2
# 60              85.000                   38.0  ...                  0
# 63              16.000                    5.5  ...                  0
# 69             167.000                   69.0  ...                  9
# 75              26.625                   10.5  ...                  6
#
#     R_win_by_Submission  R_win_by_TKO_Doctor_Stoppage  R_wins  R_Stance  \
# 4                     0                             0       3  Southpaw
# 60                    0                             0       2  Orthodox
# 63                    0                             0       0  Orthodox
# 69                    2                             0      16  Orthodox
# 75                    0                             0       9  Orthodox
#
#     R_Height_cms  R_Reach_cms  R_Weight_lbs  B_age  R_age
# 4         187.96       190.50         264.0   32.0   26.0
# 60        185.42       190.50         245.0   27.0   32.0
# 63        195.58       203.20         265.0   36.0   30.0
# 69        190.50       195.58         240.0   27.0   40.0
# 75        193.04       203.20         265.0   41.0   38.0
#
# [5 rows x 135 columns]

# %% [markdown]
# ### Correlações

# %%
data_heavy_blue_winners = data_heavy.loc[(data_heavy.Winner==0),:]
data_heavy_blue_winners = data_heavy_blue_winners.drop(['Winner'], axis=1)
data_heavy_red_winners = data_heavy.loc[(data_heavy.Winner==1),:]
data_heavy_red_winners = data_heavy_red_winners.drop(['Winner'], axis=1)

# %%
blue_winners_correlation = data_heavy_blue_winners.corr()
blue_winners_correlation.head(2)
# Out:
#                 date  title_bout  no_of_rounds  B_current_lose_streak  \
# date        1.000000   -0.161123     -0.032762               0.054294
# title_bout -0.161123    1.000000      0.491461              -0.137166
#
#             B_current_win_streak  B_draw  B_avg_BODY_att  B_avg_BODY_landed  \
# date                   -0.145747     NaN        0.274744           0.256441
# title_bout              0.345926     NaN        0.000122           0.002365
#
#             B_avg_CLINCH_att  B_avg_CLINCH_landed    ...     \
# date                0.154872             0.179436    ...
# title_bout          0.059811             0.056089    ...
#
#             R_win_by_Decision_Unanimous  R_win_by_KO/TKO  R_win_by_Submission  \
# date                           0.231107         0.255263            -0.078268
# title_bout                     0.198632         0.182796             0.064792
#
#             R_win_by_TKO_Doctor_Stoppage    R_wins  R_Height_cms  R_Reach_cms  \
# date                           -0.051332  0.205434      0.029779     0.010070
# title_bout                     -0.056728  0.181773     -0.018567     0.100335
#
#             R_Weight_lbs     B_age     R_age
# date            0.050460  0.102656  0.258130
# title_bout     -0.185558  0.014377 -0.040564
#
# [2 rows x 137 columns]

# %% [markdown]
# ### Aplicando filtros

# %%
filtros = ['R_fighter','B_fighter','Winner','weight_class','title_bout','R_wins','R_losses','B_wins','B_losses',
           'B_Reach_cms','B_Height_cms','B_Weight_lbs','R_Reach_cms','R_Height_cms','R_Weight_lbs']

# %%
data_heavy_filtered = data_heavy_util.loc[:,filtros]

# %%
data_heavy_filtered.head()
# Out:
#            R_fighter          B_fighter  Winner weight_class  title_bout  \
# 4        Tai Tuivasa      Blagoy Ivanov       0  Heavyweight           0
# 60     Arjan Bhullar         Juan Adams       1  Heavyweight           0
# 63        Greg Hardy  Dmitrii Smoliakov       1  Heavyweight           0
# 69   Andrei Arlovski      Augusto Sakai       0  Heavyweight           0
# 75  Alistair Overeem    Aleksei Oleinik       1  Heavyweight           0
#
#     R_wins  R_losses  B_wins  B_losses  B_Reach_cms  B_Height_cms  \
# 4        3         1       1         1       185.42        180.34
# 60       2         1       1         0       203.20        195.58
# 63       0         1       0         2       187.96        187.96
# 69      16        12       1         0       195.58        190.50
# 75       9         6       6         2       203.20        187.96
#
#     B_Weight_lbs  R_Reach_cms  R_Height_cms  R_Weight_lbs
# 4          250.0       190.50        187.96         264.0
# 60         265.0       190.50        185.42         245.0
# 63         253.0       203.20        195.58         265.0
# 69         265.0       195.58        190.50         240.0
# 75         240.0       203.20        193.04         265.0

# %%
data_heavy_filtered['B_Reach_cms'].corr(data_heavy_filtered['Winner'])
# Out:
# -0.10192044189964397

# %% [markdown]
# ### Modelo inicial

# %% [markdown]
# Separando em categóricos

# %%
categoricas = [
    'R_fighter', 
    'B_fighter', 
    'weight_class', 
    'R_Stance', 
    'B_Stance', 
]

data_heavy_cat = data_heavy_util[categoricas].astype('category')
data_heavy_num = data_heavy_util.drop(categoricas, axis=1).astype('float')

# %%
X = data_heavy_num.drop('Winner', axis=1)
y = data_heavy_num['Winner']

# %% [markdown]
# Separando os dados em testes e treinamento

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
model = RandomForestClassifier(n_estimators=10000)

model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10000, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
#Fatores que tem o maior peso na decisão da vitória
j=1
lista_j=list()
for i, f in sorted(list(zip(model.feature_importances_, X_train.columns)), reverse=True):
    print( j,'°:',f'{f}: {i}')
    a=str(j)+'°'
    lista_j.append(a)
    j+=1
# Out:
# 1 °: R_avg_opp_CLINCH_att: 0.022359704171831224
# 2 °: R_avg_opp_CLINCH_landed: 0.01980716771258457
# 3 °: R_age: 0.017887442423005058
# 4 °: R_avg_TD_att: 0.013481501387814655
# 5 °: R_avg_TD_landed: 0.013376475880559988
# 6 °: R_total_rounds_fought: 0.012571500739346089
# 7 °: R_losses: 0.012426902420763275
# 8 °: B_avg_HEAD_att: 0.011908518645654516
# 9 °: B_avg_opp_GROUND_att: 0.011702855781373603
# 10 °: B_avg_HEAD_landed: 0.011490510498193485
# 11 °: B_avg_SIG_STR_att: 0.01144789834855208
# 12 °: B_Weight_lbs: 0.010991403209570432
# 13 °: B_avg_BODY_att: 0.010902260070462095
# 14 °: B_avg_SIG_STR_landed: 0.01049236113982605
# 15 °: B_avg_BODY_landed: 0.010476013899575542
# 16 °: B_Reach_cms: 0.010104076881478657
# 17 °: R_avg_BODY_att: 0.010094422492484382
# 18 °: B_avg_opp_GROUND_landed: 0.00999500132903117
# 19 °: R_avg_CLINCH_att: 0.00997939112958901
# 20 °: B_age: 0.009974061556401433
# 21 °: R_avg_opp_HEAD_landed: 0.009797503056031494
# 22 °: R_avg_TD_pct: 0.009695274836469403
# 23 °: B_avg_opp_TD_att: 0.009613516629127263
# 24 °: R_win_by_KO/TKO: 0.00954975309026418
# 25 °: B_avg_DISTANCE_att: 0.009546458625063656
# 26 °: B_avg_TOTAL_STR_landed: 0.009492609082690616
# 27 °: B_avg_DISTANCE_landed: 0.009477123749745598
# 28 °: R_avg_GROUND_landed: 0.009380278199574817
# 29 °: R_avg_HEAD_landed: 0.009367310199239877
# 30 °: R_avg_GROUND_att: 0.009298856189831901
# 31 °: R_avg_opp_GROUND_att: 0.00928259923223478
# 32 °: R_avg_opp_SIG_STR_pct: 0.009227009754480153
# 33 °: R_avg_TOTAL_STR_landed: 0.009186949751094072
# 34 °: B_avg_GROUND_att: 0.00914045612251132
# 35 °: R_avg_CLINCH_landed: 0.00910436683097634
# 36 °: B_avg_opp_DISTANCE_landed: 0.009097063514558076
# 37 °: B_avg_TOTAL_STR_att: 0.009094501977141659
# 38 °: R_avg_BODY_landed: 0.009066406563867816
# 39 °: R_avg_opp_KD: 0.008920285180404575
# 40 °: R_avg_opp_HEAD_att: 0.008906968096934918
# 41 °: B_avg_LEG_att: 0.008900747824247195
# 42 °: R_avg_TOTAL_STR_att: 0.008806799025593658
# 43 °: B_avg_GROUND_landed: 0.00876660061393991
# 44 °: R_avg_opp_SIG_STR_att: 0.008759582451175559
# 45 °: B_avg_opp_TOTAL_STR_landed: 0.008722787986165426
# 46 °: R_avg_opp_DISTANCE_att: 0.008717956743595991
# 47 °: R_avg_SIG_STR_landed: 0.008701468619786983
# 48 °: B_avg_TD_att: 0.0086108990580611
# 49 °: R_avg_PASS: 0.008549775125033203
# 50 °: R_avg_DISTANCE_landed: 0.008505108336305274
# 51 °: R_avg_opp_GROUND_landed: 0.008495776836545068
# 52 °: R_wins: 0.008463512409990484
# 53 °: B_avg_LEG_landed: 0.008417407848903193
# 54 °: R_avg_opp_SIG_STR_landed: 0.008386889678142707
# 55 °: B_avg_SIG_STR_pct: 0.008312106857953036
# 56 °: R_avg_SIG_STR_pct: 0.008289900438678041
# 57 °: B_avg_opp_BODY_att: 0.008230969746590069
# 58 °: B_avg_opp_TD_pct: 0.008131612255614951
# 59 °: B_total_time_fought(seconds): 0.008120460403918785
# 60 °: B_avg_opp_SIG_STR_pct: 0.008096026744226676
# 61 °: R_avg_SIG_STR_att: 0.007994208629435366
# 62 °: B_avg_opp_PASS: 0.007952101987387722
# 63 °: B_avg_CLINCH_landed: 0.007913017437724277
# 64 °: R_avg_KD: 0.007885574468649313
# 65 °: R_avg_opp_BODY_landed: 0.007843851551777085
# 66 °: R_avg_opp_TOTAL_STR_landed: 0.007835991919123151
# 67 °: B_avg_CLINCH_att: 0.007801749208074382
# 68 °: B_avg_opp_TOTAL_STR_att: 0.007717606186291701
# 69 °: R_avg_opp_LEG_att: 0.007716892262586843
# 70 °: R_avg_DISTANCE_att: 0.007708742614123577
# 71 °: R_avg_HEAD_att: 0.007704201975324574
# 72 °: R_avg_opp_TD_att: 0.00766882893797486
# 73 °: B_avg_opp_SIG_STR_att: 0.007583180363864314
# 74 °: B_total_rounds_fought: 0.007554908470879346
# 75 °: R_avg_opp_LEG_landed: 0.007532938917760264
# 76 °: B_avg_opp_BODY_landed: 0.007387581892341418
# 77 °: B_avg_opp_CLINCH_att: 0.0073851467419344475
# 78 °: R_avg_opp_BODY_att: 0.0073753517663603515
# 79 °: R_avg_opp_DISTANCE_landed: 0.007358539504972845
# 80 °: B_avg_opp_LEG_att: 0.007344267686152972
# 81 °: B_Height_cms: 0.007311011839280458
# 82 °: B_avg_opp_CLINCH_landed: 0.007283273831946869
# 83 °: B_avg_opp_DISTANCE_att: 0.007241456447891815
# 84 °: B_avg_PASS: 0.007161812776479762
# 85 °: R_avg_LEG_att: 0.007113686275052182
# 86 °: R_avg_opp_TOTAL_STR_att: 0.006837843369581746
# 87 °: B_avg_opp_HEAD_landed: 0.0068033579721816706
# 88 °: B_avg_TD_landed: 0.006778198962433534
# 89 °: B_avg_opp_LEG_landed: 0.006773464235218675
# 90 °: R_avg_opp_TD_pct: 0.006769582000679389
# 91 °: R_total_time_fought(seconds): 0.006665715409041142
# 92 °: B_avg_opp_HEAD_att: 0.006530028003683191
# 93 °: B_avg_REV: 0.006526584145014273
# 94 °: B_avg_KD: 0.006438146477375164
# 95 °: R_avg_opp_PASS: 0.00632369578930693
# 96 °: R_Reach_cms: 0.006142283279229035
# 97 °: R_avg_LEG_landed: 0.006117666697994194
# 98 °: B_avg_opp_KD: 0.0061105785166323204
# 99 °: B_avg_TD_pct: 0.00610141641474824
# 100 °: B_avg_opp_SIG_STR_landed: 0.006061131924594396
# 101 °: B_avg_opp_TD_landed: 0.005848698796097189
# 102 °: R_avg_opp_TD_landed: 0.005752571624318045
# 103 °: R_avg_opp_SUB_ATT: 0.0053321411585704895
# 104 °: R_current_win_streak: 0.005065071909190053
# 105 °: B_losses: 0.004934421979641252
# 106 °: B_win_by_KO/TKO: 0.004862298154678346
# 107 °: R_avg_SUB_ATT: 0.004736649516627898
# 108 °: B_wins: 0.004587543438462489
# 109 °: B_avg_opp_SUB_ATT: 0.004585072041219124
# 110 °: R_Height_cms: 0.004491870030790746
# 111 °: R_longest_win_streak: 0.004383187574121875
# 112 °: R_Weight_lbs: 0.004329608091286299
# 113 °: B_avg_SUB_ATT: 0.004144420325360666
# 114 °: B_longest_win_streak: 0.003920352102357799
# 115 °: R_avg_opp_REV: 0.0034520316733201595
# 116 °: B_avg_opp_REV: 0.0033351144706551617
# 117 °: B_current_win_streak: 0.0031731070401550994
# 118 °: R_win_by_Decision_Unanimous: 0.002967887548578403
# 119 °: R_current_lose_streak: 0.0029322997609135884
# 120 °: B_current_lose_streak: 0.0028914599022909445
# 121 °: R_win_by_Submission: 0.002879840891667735
# 122 °: R_total_title_bouts: 0.002517377479596838
# 123 °: R_avg_REV: 0.0025118295898995703
# 124 °: B_win_by_Decision_Unanimous: 0.002501580398581967
# 125 °: B_win_by_Submission: 0.001789428691703764
# 126 °: B_total_title_bouts: 0.001766785151194588
# 127 °: no_of_rounds: 0.001266762578681598
# 128 °: B_win_by_TKO_Doctor_Stoppage: 0.0010258895214963096
# 129 °: R_win_by_Decision_Split: 0.000873954115586615
# 130 °: B_win_by_Decision_Split: 0.0007892185455351022
# 131 °: R_win_by_Decision_Majority: 0.0007189450468097666
# 132 °: R_win_by_TKO_Doctor_Stoppage: 0.0005976606245629088
# 133 °: title_bout: 0.0005297526145975937
# 134 °: B_win_by_Decision_Majority: 0.0004484013155390822
# 135 °: R_draw: 0.0
# 136 °: B_draw: 0.0

# %%
data={'Fator':X_train.columns ,'Correlação':model.feature_importances_,}
Fator_por_corr=pd.DataFrame(data)
Fator_por_corr=Fator_por_corr.sort_values(by='Correlação', ascending=False)
Fator_por_corr['Grau de Importância']=lista_j
Fator_por_corr = Fator_por_corr.set_index('Grau de Importância')
Fator_por_corr.head()
# Out:
#                                        Fator  Correlação
# Grau de Importância
# 1°                      R_avg_opp_CLINCH_att    0.022360
# 2°                   R_avg_opp_CLINCH_landed    0.019807
# 3°                                     R_age    0.017887
# 4°                              R_avg_TD_att    0.013482
# 5°                           R_avg_TD_landed    0.013376

# %%
inuteis = []
uteis = []
for index,row in Fator_por_corr.iterrows():
    if row['Correlação'] >= -0.01 and row['Correlação']<=0.01:
        inuteis.append(row['Fator'])
    else:
        uteis.append(row['Fator'])

# %%
data_heavy_util_relevante = data_heavy_util.loc[:,uteis]
data_heavy_util_relevante.head()
# Out:
#     R_avg_opp_CLINCH_att  R_avg_opp_CLINCH_landed  R_age  R_avg_TD_att  \
# 4               4.500000                 3.500000   26.0      0.500000
# 60              8.000000                 5.333333   32.0      2.000000
# 63              2.000000                 1.000000   30.0      0.000000
# 69              4.964286                 3.035714   40.0      0.892857
# 75              6.466667                 4.200000   38.0      0.866667
#
#     R_avg_TD_landed  R_total_rounds_fought  R_losses  B_avg_HEAD_att  \
# 4          0.000000                      7         1           184.5
# 60         1.333333                      8         1           131.0
# 63         0.000000                      2         1            15.5
# 69         0.321429                     59        12           169.0
# 75         0.266667                     29         6            28.5
#
#     B_avg_opp_GROUND_att  B_avg_HEAD_landed  B_avg_SIG_STR_att  B_Weight_lbs  \
# 4                  0.000               45.0             203.50         250.0
# 60                 2.000               74.0             144.00         265.0
# 63                28.500                5.0              22.00         253.0
# 69                 0.000               81.0             218.00         265.0
# 75                 3.625               11.5              35.25         240.0
#
#     B_avg_BODY_att  B_avg_SIG_STR_landed  B_avg_BODY_landed  B_Reach_cms  \
# 4            17.00                 61.50             14.500       185.42
# 60            8.00                 86.00              8.000       203.20
# 63            5.00                  9.50              3.500       187.96
# 69           35.00                111.00             21.000       195.58
# 75            4.25                 17.25              3.875       203.20
#
#     R_avg_BODY_att
# 4         7.750000
# 60        2.000000
# 63        5.000000
# 69        6.607143
# 75       13.466667

# %%
def relevancia(df,coluna_nome,coluna_correlacao,acuracia):
    inuteis = []
    uteis = []
    for index,row in df.iterrows():
        if row[coluna_correlacao] >= -acuracia and row[coluna_correlacao] <= acuracia:
            inuteis.append(row[coluna_nome])
        else:
            uteis.append(row[coluna_nome])
    return uteis

# %%
relevancia(Fator_por_corr,'Fator','Correlação',0.01)
# Out:
# [['B_avg_opp_GROUND_landed',
#   'R_avg_CLINCH_att',
#   'B_age',
#   'R_avg_opp_HEAD_landed',
#   'R_avg_TD_pct',
#   'B_avg_opp_TD_att',
#   'R_win_by_KO/TKO',
#   'B_avg_DISTANCE_att',
#   'B_avg_TOTAL_STR_landed',
#   'B_avg_DISTANCE_landed',
#   'R_avg_GROUND_landed',
#   'R_avg_HEAD_landed',
#   'R_avg_GROUND_att',
#   'R_avg_opp_GROUND_att',
#   'R_avg_opp_SIG_STR_pct',
#   'R_avg_TOTAL_STR_landed',
#   'B_avg_GROUND_att',
#   'R_avg_CLINCH_landed',
#   'B_avg_opp_DISTANCE_landed',
#   'B_avg_TOTAL_STR_att',
#   'R_avg_BODY_landed',
#   'R_avg_opp_KD',
#   'R_avg_opp_HEAD_att',
#   'B_avg_LEG_att',
#   'R_avg_TOTAL_STR_att',
#   'B_avg_GROUND_landed',
#   'R_avg_opp_SIG_STR_att',
#   'B_avg_opp_TOTAL_STR_landed',
#   'R_avg_opp_DISTANCE_att',
#   'R_avg_SIG_STR_landed',
#   'B_avg_TD_att',
#   'R_avg_PASS',
#   'R_avg_DISTANCE_landed',
#   'R_avg_opp_GROUND_landed',
#   'R_wins',
#   'B_avg_LEG_landed',
#   'R_avg_opp_SIG_STR_landed',
#   'B_avg_SIG_STR_pct',
#   'R_avg_SIG_STR_pct',
#   'B_avg_opp_BODY_att',
#   'B_avg_opp_TD_pct',
#   'B_total_time_fought(seconds)',
#   'B_avg_opp_SIG_STR_pct',
#   'R_avg_SIG_STR_att',
#   'B_avg_opp_PASS',
#   'B_avg_CLINCH_landed',
#   'R_avg_KD',
#   'R_avg_opp_BODY_landed',
#   'R_avg_opp_TOTAL_STR_landed',
#   'B_avg_CLINCH_att',
#   'B_avg_opp_TOTAL_STR_att',
#   'R_avg_opp_LEG_att',
#   'R_avg_DISTANCE_att',
#   'R_avg_HEAD_att',
#   'R_avg_opp_TD_att',
#   'B_avg_opp_SIG_STR_att',
#   'B_total_rounds_fought',
#   'R_avg_opp_LEG_landed',
#   'B_avg_opp_BODY_landed',
#   'B_avg_opp_CLINCH_att',
#   'R_avg_opp_BODY_att',
#   'R_avg_opp_DISTANCE_landed',
#   'B_avg_opp_LEG_att',
#   'B_Height_cms',
#   'B_avg_opp_CLINCH_landed',
#   'B_avg_opp_DISTANCE_att',
#   'B_avg_PASS',
#   'R_avg_LEG_att',
#   'R_avg_opp_TOTAL_STR_att',
#   'B_avg_opp_HEAD_landed',
#   'B_avg_TD_landed',
#   'B_avg_opp_LEG_landed',
#   'R_avg_opp_TD_pct',
#   'R_total_time_fought(seconds)',
#   'B_avg_opp_HEAD_att',
#   'B_avg_REV',
#   'B_avg_KD',
#   'R_avg_opp_PASS',
#   'R_Reach_cms',
#   'R_avg_LEG_landed',
#   'B_avg_opp_KD',
#   'B_avg_TD_pct',
#   'B_avg_opp_SIG_STR_landed',
#   'B_avg_opp_TD_landed',
#   'R_avg_opp_TD_landed',
#   'R_avg_opp_SUB_ATT',
#   'R_current_win_streak',
#   'B_losses',
#   'B_win_by_KO/TKO',
#   'R_avg_SUB_ATT',
#   'B_wins',
#   'B_avg_opp_SUB_ATT',
#   'R_Height_cms',
#   'R_longest_win_streak',
#   'R_Weight_lbs',
#   'B_avg_SUB_ATT',
#   'B_longest_win_streak',
#   'R_avg_opp_REV',
#   'B_avg_opp_REV',
#   'B_current_win_streak',
#   'R_win_by_Decision_Unanimous',
#   'R_current_lose_streak',
#   'B_current_lose_streak',
#   'R_win_by_Submission',
#   'R_total_title_bouts',
#   'R_avg_REV',
#   'B_win_by_Decision_Unanimous',
#   'B_win_by_Submission',
#   'B_total_title_bouts',
#   'no_of_rounds',
#   'B_win_by_TKO_Doctor_Stoppage',
#   'R_win_by_Decision_Split',
#   'B_win_by_Decision_Split',
#   'R_win_by_Decision_Majority',
#   'R_win_by_TKO_Doctor_Stoppage',
#   'title_bout',
#   'B_win_by_Decision_Majority',
#   'R_draw',
#   'B_draw'],
#  ['R_avg_opp_CLINCH_att',
#   'R_avg_opp_CLINCH_landed',
#   'R_age',
#   'R_avg_TD_att',
#   'R_avg_TD_landed',
#   'R_total_rounds_fought',
#   'R_losses',
#   'B_avg_HEAD_att',
#   'B_avg_opp_GROUND_att',
#   'B_avg_HEAD_landed',
#   'B_avg_SIG_STR_att',
#   'B_Weight_lbs',
#   'B_avg_BODY_att',
#   'B_avg_SIG_STR_landed',
#   'B_avg_BODY_landed',
#   'B_Reach_cms',
#   'R_avg_BODY_att']]
